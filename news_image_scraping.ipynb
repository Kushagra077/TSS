# %%
import os
import requests
from bs4 import BeautifulSoup
from googlesearch import search

def search_articles(query, num_results):
    # Perform Google search and retrieve news articles only
    search_query = query + " news article"

    articles = []
    counter = 0  # Track the number of articles found

    for url in search(search_query, stop=num_results):
        if 'twitter.com' in url or 'facebook.com' in url:
            continue  # Skip social media links

        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract article title
        title = soup.find('title').get_text()

        # Extract article summary (if available)
        summary_tag = soup.find('meta', attrs={'name': 'description'})
        summary = summary_tag.get('content') if summary_tag else None

        # Extract all image tags from the article
        image_tags = soup.find_all('img')

        # Create a folder for the article's images
        folder_name = ''.join(c if c.isalnum() else '_' for c in title)
        os.makedirs(folder_name, exist_ok=True)

        image_info = []
        for i, img_tag in enumerate(image_tags):
            image_data = {}

            # Extract image source attribute(s)
            src = img_tag.get('src')
            if src and src.startswith(('http://', 'https://')):
                image_data['src'] = src

            dataset_src = img_tag.get('dataset-src')
            if dataset_src and dataset_src.startswith(('http://', 'https://')):
                image_data['dataset-src'] = dataset_src

            # Download and save each image in the folder
            for attr_name, img_link in image_data.items():
                img_data = requests.get(img_link).content
                img_path = os.path.join(folder_name, f'image_{i}_{attr_name}.jpg')
                with open(img_path, 'wb') as img_file:
                    img_file.write(img_data)

            image_info.append(image_data)

        # Store article data in a dictionary
        article_data = {
            'title': title,
            'url': url,
            'summary': summary,
            'images': image_info
        }
        articles.append(article_data)
        # Create a text file with article information
        text_file_path = os.path.join(folder_name, 'article_info.txt')
        with open(text_file_path, 'w') as text_file:
            text_file.write(f"Title: {title}\n")
            text_file.write(f"Summary: {summary}\n")
            text_file.write(f"URL: {url}\n")

        counter += 1
        if counter == num_results:
            break  # Stop retrieving more articles once desired count is reached

    return articles

# Example usage
query = input("Enter your search query: ")
num_results = int(input("Enter the number of articles to retrieve: "))
articles = search_articles(query, num_results)

# Display the retrieved article data
for i, article in enumerate(articles, start=1):
    print(f"Article {i}:")
    print("Title:", article['title'])
    print("URL:", article['url'])
    print("Summary:", article['summary'])
    print("Images:")
    for img_info in article['images']:
        for attr_name, img_link in img_info.items():
            print(f"Attribute: {attr_name}")
            print("Image Link:", img_link)
            print()
    print()
# Out:
# Enter your search query: mehul choksi
# Enter the number of articles to retrieve: 3
# Article 1:
# Title: ‘Mehul Choksi can’t be removed from Antigua and Barbuda’: What the court ruled | Explained News,The Indian Express
# URL: https://indianexpress.com/article/explained/mehul-choksi-cannot-be-removed-antigua-8557711/
# Summary: According to Mehul Choksi's account, in 2021, RAW agents kidnapped him, torturing him and coercing him to admit to wrongdoing.
# Images:
# Attribute: src
# Image Link: https://sb.scorecardresearch.com/p?c1=2&c2=8738137&cv=2.0&cj=1
#
# Attribute: src
# Image Link: https://www.facebook.com/tr?id=444470064056909&ev=PageView&noscript=1
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/facebook-icon.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/twitter-icon.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/youtube-icon.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/IE-insta-grey.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/indian-express-logo-n.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icon-newsguard.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icon-whatsapp.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icon-fb.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icon-twitter.svg
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/04/ch1170935.jpg?w=640
#
# Attribute: src
# Image Link: https://data.indianexpress.com/election2019/track_1x1.jpg
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/Kejriwal-lg-saxena.jpg?resize=450,250
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/02/ranimukerji.jpg?resize=450,250
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/Martha-Stewart-Final.jpg?resize=450,250
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/PTI05_14_2023_000126B.jpg?resize=450,250
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icon-whatsapp.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icon-fb.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icon-twitter.svg
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/kuno-cheetah-death.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/alzeihmers.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/2023-05-16T081753Z_1780146848_UP1EJ5G0N1R2A_RTRMADP_5_FILMFESTIVAL-CANNES-OPENING-MORNING.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/ch1747174.jpeg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/04/The-main-square-of-Maliana-village-Meerut-district-Monday.-The-1987-violence-took-place-in-the-adjoining-lanes.-Gajendra-Yadav.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/04/rahul-gandhi-1.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/sardar-udham-pcs.png?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/cannes-india-day-1-1200-1.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/cheerleaders-CSK-fan.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/Man-surprises-girlfriend-with-photo-at-Times-Square.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/moshin-khan.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/Nur-Mohammed-Hasan.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/Congress-Karnataka-Win.jpeg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/kuno-cheetah-death.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/bill-gates-reuters.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/5.png?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/moshin-khan.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/Nur-Mohammed-Hasan.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/wmo.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/5.png?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/worldcoin-orb-featured.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/flashco.jpeg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/bill-gates-reuters.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/Congress-Karnataka-Win.jpeg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/women-1.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/aryan-1.jpeg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/river-DISPUTE.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/akola-clash-2.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/CHATBOT-STYLIST.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/Krunal-Pandya-Ashwin-1.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/PM-Narendra-Modi.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/Canva-Student-Font-13.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/ranchi-athelete.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/Amrit-Udyan-1.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/dead-759-4-1.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/SKW.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://images.indianexpress.com/2023/05/TN-EB-Minister-Senthil-Balaji.jpg?resize=150,83
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-facebook.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-twitter.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-linkedin.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-instagram.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-android.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/icons/icon-apple.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/newsguard-logo-w.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/newsguard-check.svg
#
# Attribute: src
# Image Link: https://indianexpress.com/wp-content/themes/indianexpress/images/vip-powered-logo.png
#
#
# Article 2:
# Title: Mehul choksi | Latest News on Mehul-choksi | Breaking Stories and Opinion Articles - Firstpost
# URL: https://www.firstpost.com/tag/mehul-choksi
# Summary: Latest News on Mehul choksi. Read breaking stories and opinion articles on mehul-choksi at Firstpost
# Images:
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fp-desk-logo.png
#
# Attribute: src
# Image Link: https://www.firstpost.com//static/images/149071.png
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fplogo_placeholder_640x362.jpg
#
# Attribute: src
# Image Link: https://www.firstpost.com/static/images/fp-logo.png
#
#
# Article 3:
# Title: mehul choksi: Latest News & Videos, Photos about mehul choksi  | The Economic Times - Page 1
# URL: https://economictimes.indiatimes.com/topic/mehul-choksi
# Summary: mehul choksi Latest Breaking News, Pictures, Videos, and Special Reports from The Economic Times. mehul choksi  Blogs, Comments and Archive News on Economictimes.com
# Images:
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/photo/msid-76931895,quality-100/et-logo.jpg
#
# Attribute: src
# Image Link: https://img.etimg.com/photo/msid-100067830,quality-100/et-logo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://economictimes.indiatimes.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://img.etimg.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://img.etimg.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://img.etimg.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://img.etimg.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://img.etimg.com/thumb/width-100,height-75,msid-42031747/etlogo.jpg
#
# Attribute: src
# Image Link: https://img.etimg.com/photo/msid-74462387,quality-100/et-logo.jpg
#
# Attribute: src
# Image Link: https://img.etimg.com/photo/msid-74451948,quality-100/et-logo.jpg
